# %% [markdown]
# # Creating Tensors Lab
#
# Companion to `book/02-pytorch/01-creating-tensors.md`.

# %%
import torch

# %%
a = torch.tensor([[1.0, 2.0], [3.0, 4.0]])
b = torch.zeros(2, 3)
c = torch.randn(4)
print(a.shape, a.dtype)
print(b)
print(c)

# %% [markdown]
# ## Try it
#
# Create a 3×3 identity tensor.

# %%
# Your code here
