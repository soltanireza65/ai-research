# %% [markdown]
# # Transposing Tensors Lab
#
# Companion to `book/02-pytorch/03-transposing-tensors.md`.

# %%
import torch

# %%
A = torch.arange(6).reshape(2, 3)
print(A)
print('A.T =\n', A.T)
print('shape:', A.T.shape)

# %% [markdown]
# ## Try it
#
# Transpose a 3D tensor along dims 0 and 2.

# %%
# Your code here
